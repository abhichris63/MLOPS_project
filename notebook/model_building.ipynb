# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Abcom\Desktop\mlops_project\Data\archive\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
284807 - 1081
# Out:
# 283726

# %%
df[df.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# #### - It is Imbalance Dataset

# %%
df['Class'].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %% [markdown]
# ### **Splitting the Dataset**

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,y,
    test_size=0.2,
    stratify=y, 
    random_state=42
)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
X_train[['Amount','Time']]
# Out:
#         Amount      Time
# 226238   32.00  144549.0
# 134253    6.99   80716.0
# 186465   14.95  127116.0
# 149493   17.30   91342.0
# 18461    24.00   29522.0
# ...        ...       ...
# 225116  124.00  144113.0
# 3525    261.80    3013.0
# 242674   37.00  151594.0
# 60594     5.00   49395.0
# 67057    12.31   52346.0
#
# [226980 rows x 2 columns]

# %%
X_train[['Amount','Time']] = scaler.fit_transform(X_train[['Amount','Time']])

# %%
X_train[['Amount','Time']]
# Out:
#           Amount      Time
# 226238 -0.229434  1.045499
# 134253 -0.331197 -0.298690
# 186465 -0.298809  0.678397
# 149493 -0.289247 -0.074929
# 18461  -0.261985 -1.376728
# ...          ...       ...
# 225116  0.144905  1.036318
# 3525    0.705600 -1.934952
# 242674 -0.209089  1.193852
# 60594  -0.339294 -0.958245
# 67057  -0.309550 -0.896103
#
# [226980 rows x 2 columns]

# %%
X_test[['Amount','Time']]
# Out:
#         Amount      Time
# 86568    11.50   61290.0
# 251557    1.94  155394.0
# 20232    91.28   30881.0
# 68952   228.00   53203.0
# 191852    1.41  129429.0
# ...        ...       ...
# 56516     2.00   47464.0
# 188431    9.99  127974.0
# 115561    9.14   73912.0
# 187644    0.89  127623.0
# 8267     15.95   11067.0
#
# [56746 rows x 2 columns]

# %%
X_test[['Amount','Time']] = scaler.transform(X_test[['Amount','Time']])

# %%
X_test[['Amount','Time']]
# Out:
#           Amount      Time
# 86568  -0.312846 -0.707761
# 251557 -0.351745  1.273872
# 20232   0.011771 -1.348111
# 68952   0.568071 -0.878056
# 191852 -0.353901  0.727104
# ...          ...       ...
# 56516  -0.351501 -0.998907
# 188431 -0.318990  0.696464
# 115561 -0.322449 -0.441968
# 187644 -0.356017  0.689073
# 8267   -0.294740 -1.765352
#
# [56746 rows x 2 columns]

# %%
# Fit on Train
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

X_train_scaled[['Amount','Time']] = scaler.fit_transform(X_train[['Amount','Time']])

X_test_scaled[['Amount','Time']] = scaler.transform(X_test[['Amount','Time']])

# %%
lr.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
y_pred = lr.predict(X_test_scaled)
y_pred_prob = lr.predict_proba(X_test_scaled)[:,1]

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)

print(cm)
# Out:
# [[55258  1393]
#  [   12    83]]

# %% [markdown]
#     [[TN FP]
#     [FN TP]]

# %%
from sklearn.metrics import roc_auc_score

roc = roc_auc_score(y_test, y_pred_prob)

print(roc)
# Out:
# 0.9658392242808925

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, thresolds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)

# %% [markdown]
# #### Why we should not do fit_transform on test dataset ?
#
# - To avoid Data Leakage

# %%
# Apply some Class Weights

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000, class_weight='balanced')
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# Out:
# array([0.02177687, 0.02032174, 0.01003082, ..., 0.04129319, 0.0458121 ,
#        0.02693454], shape=(56746,))

# %%
# Predictions

y_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(lr.predict_proba(X_test))[:,1] # Probability of Fraud (Class 1)
# Out:
# c:\Users\Abcom\anaconda3\envs\mlops_1_venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 4
#       1 # Predictions
#       3 y_pred = lr.predict(X_test)
# ----> 4 y_pred_prob = lr.predict_proba(lr.predict_proba(X_test))[:,1] # Probability of Fraud (Class 1)
#
# File c:\Users\Abcom\anaconda3\envs\mlops_1_venv\lib\site-packages\sklearn\linear_model\_logistic.py:1462, in LogisticRegression.predict_proba(self, X)
#    1457 ovr = self.multi_class in ["ovr", "warn"] or (
#    1458     self.multi_class in ["auto", "deprecated"]
#    1459     and (self.classes_.size <= 2 or self.solver == "liblinear")
#    1460 )
#    1461 if ovr:
# -> 1462     return super()._predict_proba_lr(X)
# ...
